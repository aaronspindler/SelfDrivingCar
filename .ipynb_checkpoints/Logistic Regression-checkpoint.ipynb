# %%
import numpy as np
import matplotlib.pyplot as plt

def draw(x1, x2):
    line = plt.plot(x1, x2)
    plt.pause(0.0001)
    line[0].remove()
    
def sigmoid(score):
    return 1/(1+ np.exp(-score))

def calculate_error(line_parameters, points, y):
    m = points.shape[0]
    p = sigmoid(points * line_parameters)
    cross_entropy = -(1/m)*(np.log(p).transpose() * y + np.log(1-p).transpose()*(1-y))
    return cross_entropy

def gradient_descent(line_parameters, points, y, alpha):
    for i in range(2000):
        m = points.shape[0]
        p = sigmoid(points * line_parameters)
        gradient = (points.transpose() * (p - y))*(1/m)
        line_parameters = line_parameters - (gradient * alpha)
        w1 = line_parameters.item(0)
        w2 = line_parameters.item(1)
        b = line_parameters.item(2)
        x1 = np.array([points[:, 0].min(), points[:, 0].max()])
        x2 = -b / w2 + x1 * (- w1 /w2 )
        draw(x1, x2)

num_points = 100
np.random.seed(0)
bias = np.ones(num_points)
top_region = np.array([np.random.normal(10, 2, num_points), np.random.normal(12, 2, num_points), bias]).transpose()
bottom_region = np.array([np.random.normal(5, 2, num_points), np.random.normal(6, 2, num_points), bias]).transpose()
all_points = np.vstack((top_region, bottom_region))
line_parameters = np.matrix([0, 0, 0]).transpose()


y = np.array([np.zeros(num_points), np.ones(num_points)]).reshape(num_points * 2, 1)

_, ax = plt.subplots(figsize=(4,4))
ax.scatter(top_region[:, 0], top_region[:, 1], color='r')
ax.scatter(bottom_region[:, 0], bottom_region[:, 1], color='b')
gradient_descent(line_parameters, all_points, y, 0.06)
plt.show()
# Out:
# -------------------------------------------------------------------
# KeyboardInterrupt                 Traceback (most recent call last)
# <ipython-input-77-30c700593b5b> in <module>
#      43 ax.scatter(top_region[:, 0], top_region[:, 1], color='r')
#      44 ax.scatter(bottom_region[:, 0], bottom_region[:, 1], color='b')
# ---> 45 gradient_descent(line_parameters, all_points, y, 0.06)
#      46 plt.show()
#
# <ipython-input-77-30c700593b5b> in gradient_descent(line_parameters, points, y, alpha)
#      27         x1 = np.array([points[:, 0].min(), points[:, 0].max()])
#      28         x2 = -b / w2 + x1 * (- w1 /w2 )
# ---> 29         draw(x1, x2)
#      30
#      31 num_points = 100
#
# <ipython-input-77-30c700593b5b> in draw(x1, x2)
#       4 def draw(x1, x2):
#       5     line = plt.plot(x1, x2)
# ----> 6     plt.pause(0.0001)
#       7     line[0].remove()
#       8
#
# H:\ProgramFiles\Anaconda\lib\site-packages\matplotlib\pyplot.py in pause(interval)
#     307         if canvas.figure.stale:
#     308             canvas.draw_idle()
# --> 309         show(block=False)
#     310         canvas.start_event_loop(interval)
#     311     else:
#
# H:\ProgramFiles\Anaconda\lib\site-packages\matplotlib\pyplot.py in show(*args, **kw)
#     267     """
#     268     global _show
# --> 269     return _show(*args, **kw)
#     270
#     271
#
# H:\ProgramFiles\Anaconda\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# H:\ProgramFiles\Anaconda\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     304             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     305         else:
# --> 306             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     307             if not format_dict:
#     308                 # nothing to display (e.g. _ipython_display_ took over)
#
# H:\ProgramFiles\Anaconda\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <H:\ProgramFiles\Anaconda\lib\site-packages\decorator.py:decorator-gen-9> in __call__(self, obj)
#
# H:\ProgramFiles\Anaconda\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# H:\ProgramFiles\Anaconda\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# H:\ProgramFiles\Anaconda\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# H:\ProgramFiles\Anaconda\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# H:\ProgramFiles\Anaconda\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2058                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#    2059                     bbox_inches = self.figure.get_tightbbox(renderer,
# -> 2060                             bbox_extra_artists=bbox_artists)
#    2061                     pad = kwargs.pop("pad_inches", None)
#    2062                     if pad is None:
#
# H:\ProgramFiles\Anaconda\lib\site-packages\matplotlib\figure.py in get_tightbbox(self, renderer, bbox_extra_artists)
#    2365
#    2366         for a in artists:
# -> 2367             bbox = a.get_tightbbox(renderer)
#    2368             if bbox is not None and (bbox.width != 0 or bbox.height != 0):
#    2369                 bb.append(bbox)
#
# H:\ProgramFiles\Anaconda\lib\site-packages\matplotlib\axes\_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists)
#    4357                 bb.append(bb_xaxis)
#    4358
# -> 4359             bb_yaxis = self.yaxis.get_tightbbox(renderer)
#    4360             if bb_yaxis:
#    4361                 bb.append(bb_yaxis)
#
# H:\ProgramFiles\Anaconda\lib\site-packages\matplotlib\axis.py in get_tightbbox(self, renderer)
#    1162         ticks_to_draw = self._update_ticks()
#    1163
# -> 1164         self._update_label_position(renderer)
#    1165
#    1166         # go back to just this axis's tick labels
#
# H:\ProgramFiles\Anaconda\lib\site-packages\matplotlib\axis.py in _update_label_position(self, renderer)
#    2317                 # use axes if spine doesn't exist
#    2318                 spinebbox = self.axes.bbox
# -> 2319             bbox = mtransforms.Bbox.union(bboxes + [spinebbox])
#    2320             left = bbox.x0
#    2321             self.label.set_position(
#
# H:\ProgramFiles\Anaconda\lib\site-packages\matplotlib\transforms.py in union(bboxes)
#     703         x1 = np.max([bbox.xmax for bbox in bboxes])
#     704         y0 = np.min([bbox.ymin for bbox in bboxes])
# --> 705         y1 = np.max([bbox.ymax for bbox in bboxes])
#     706         return Bbox([[x0, y0], [x1, y1]])
#     707
#
# H:\ProgramFiles\Anaconda\lib\site-packages\matplotlib\transforms.py in <listcomp>(.0)
#     703         x1 = np.max([bbox.xmax for bbox in bboxes])
#     704         y0 = np.min([bbox.ymin for bbox in bboxes])
# --> 705         y1 = np.max([bbox.ymax for bbox in bboxes])
#     706         return Bbox([[x0, y0], [x1, y1]])
#     707
#
# H:\ProgramFiles\Anaconda\lib\site-packages\matplotlib\transforms.py in ymax(self)
#     363     def ymax(self):
#     364         """The top edge of the bounding box."""
# --> 365         return np.max(self.get_points()[:, 1])
#     366
#     367     @property
#
# H:\ProgramFiles\Anaconda\lib\site-packages\numpy\core\fromnumeric.py in amax(a, axis, out, keepdims, initial)
#    2503     """
#    2504     return _wrapreduction(a, np.maximum, 'max', axis, None, out, keepdims=keepdims,
# -> 2505                           initial=initial)
#    2506
#    2507
#
# H:\ProgramFiles\Anaconda\lib\site-packages\numpy\core\fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      84                 return reduction(axis=axis, out=out, **passkwargs)
#      85
# ---> 86     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      87
#      88
#
# KeyboardInterrupt:
